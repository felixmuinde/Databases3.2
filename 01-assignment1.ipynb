# %%
# Testing the connection first

import pymysql as pms
import pandas as pd
from sqlalchemy import create_engine


CONSTRING = 'mysql+mysqlconnector://root:42069@127.0.0.1:3306/md_water_services'
ENGINE = create_engine(CONSTRING)

# Check for connection.
if(CONSTRING):
    print("Successfully connected")
else:
    print("Connection failed:(")
# Out:
# Successfully connected

# %%
df = pd.read_sql_query("SELECT * FROM data_dictionary LIMIT 10", ENGINE)
df
# Out:
#   table_name           column_name  \
# 0   employee  assigned_employee_id
# 1   employee         employee_name
# 2   employee          phone_number
# 3   employee                 email
# 4   employee               address
# 5   employee             town_name
# 6   employee         province_name
# 7   employee              position
# 8     visits             record_id
# 9     visits           location_id
#
#                                        description      datatype  \
# 0              Unique ID assigned to each employee           INT
# 1                             Name of the employee  VARCHAR(255)
# 2                   Contact number of the employee   VARCHAR(15)
# 3                    Email address of the employee  VARCHAR(255)
# 4              Residential address of the employee  VARCHAR(255)
# 5      Name of the town where the employee resides  VARCHAR(255)
# 6  Name of the province where the employee resides  VARCHAR(255)
# ...

# %%
dfA = pd.read_sql_query("SELECT * FROM employee LIMIT 10", ENGINE)
dfA
# Out:
#    assigned_employee_id   employee_name   phone_number email  \
# 0                     0     Amara Jengo  +99637993287   None
# 1                     1     Bello Azibo  +99643864786   None
# 2                     2    Bakari Iniko  +99222599041   None
# 3                     3  Malachi Mavuso  +99945849900   None
# 4                     4    Cheche Buhle  +99381679640   None
# 5                     5  Zuriel Matembo  +99034075111   None
# 6                     6    Deka Osumare  +99379364631   None
# 7                     7  Lalitha Kaburi  +99681623240   None
# 8                     8     Enitan Zuri  +99248509202   None
# 9                    10       Farai Nia  +99570082739   None
#
#                      address province_name town_name        position
# 0    36 Pwani Mchangani Road        Sokoto    Ilanga  Field Surveyor
# 1      129 Ziwa La Kioo Road      Kilimani     Rural  Field Surveyor
# 2     18 Mlima Tazama Avenue       Hawassa     Rural  Field Surveyor
# ...

# %%
dfB = pd.read_sql_query("SELECT * FROM global_water_access LIMIT 10", ENGINE)
dfB
# Out:
#              name                      region  year      pop_n   pop_u  \
# 0     Afghanistan                  South Asia  2015  34413.600  24.803
# 1     Afghanistan                  South Asia  2020  38928.300  26.026
# 2         Albania       Europe & Central Asia  2015   2890.520  57.434
# 3         Albania       Europe & Central Asia  2020   2877.800  62.112
# 4         Algeria  Middle East & North Africa  2015  39728.000  70.848
# 5         Algeria  Middle East & North Africa  2020  43851.000  73.733
# 6  American Samoa         East Asia & Pacific  2015     55.806  87.238
# 7  American Samoa         East Asia & Pacific  2020     55.197  87.153
# 8         Andorra       Europe & Central Asia  2015     77.993  88.345
# 9         Andorra       Europe & Central Asia  2020     77.265  87.916
#
#    wat_bas_n  wat_lim_n  wat_unimp_n  wat_sur_n  wat_bas_r  wat_lim_r  \
# 0    61.3398    3.51120    22.168800  12.980200    52.9885    3.86114
# ...

# %%
dfC = pd.read_sql_query("SELECT * FROM location LIMIT 10", ENGINE)
dfC
# Out:
#   location_id               address province_name town_name location_type
# 0   AkHa00000    2 Addis Ababa Road        Akatsi    Harare         Urban
# 1   AkHa00001   10 Addis Ababa Road        Akatsi    Harare         Urban
# 2   AkHa00002    9 Addis Ababa Road        Akatsi    Harare         Urban
# 3   AkHa00003  139 Addis Ababa Road        Akatsi    Harare         Urban
# 4   AkHa00004   17 Addis Ababa Road        Akatsi    Harare         Urban
# 5   AkHa00005  125 Addis Ababa Road        Akatsi    Harare         Urban
# 6   AkHa00006   98 Addis Ababa Road        Akatsi    Harare         Urban
# 7   AkHa00007   21 Addis Ababa Road        Akatsi    Harare         Urban
# 8   AkHa00008   11 Addis Ababa Road        Akatsi    Harare         Urban
# 9   AkHa00009    6 Addis Ababa Road        Akatsi    Harare         Urban

# %%
dfD = pd.read_sql_query("SELECT * FROM visits LIMIT 10", ENGINE)
dfD
# Out:
#    record_id location_id     source_id      time_of_record  visit_count  \
# 0          0   SoIl32582  SoIl32582224 2021-01-01 09:10:00            1
# 1          1   KiRu28935  KiRu28935224 2021-01-01 09:17:00            1
# 2          2   HaRu19752  HaRu19752224 2021-01-01 09:36:00            1
# 3          3   AkLu01628  AkLu01628224 2021-01-01 09:53:00            1
# 4          4   AkRu03357  AkRu03357224 2021-01-01 10:11:00            1
# 5          5   KiRu29315  KiRu29315224 2021-01-01 10:17:00            1
# 6          6   AkRu05234  AkRu05234224 2021-01-01 10:18:00            1
# 7          7   KiRu28520  KiRu28520224 2021-01-01 10:28:00            1
# 8          8   HaZa21742  HaZa21742224 2021-01-01 10:37:00            1
# 9          9   AmDa12214  AmDa12214224 2021-01-01 10:58:00            1
#
#    time_in_queue  assigned_employee_id
# 0             15                    12
# 1              0                    46
# 2             62                    40
# ...

# %%
dfE = pd.read_sql_query("SELECT * FROM water_quality LIMIT 10", ENGINE)
dfE
# Out:
#    record_id  subjective_quality_score  visit_count
# 0          0                         0            1
# 1          1                         1            1
# 2          2                         5            1
# 3          3                        10            1
# 4          4                         4            1
# 5          5                         0            1
# 6          6                         9            1
# 7          7                        10            1
# 8          8                         2            1
# 9          9                        10            1

# %%
dfF = pd.read_sql_query("SELECT * FROM water_source LIMIT 10", ENGINE)
dfF
# Out:
#       source_id type_of_water_source  number_of_people_served
# 0  AkHa00000224          tap_in_home                      956
# 1  AkHa00001224   tap_in_home_broken                      930
# 2  AkHa00002224   tap_in_home_broken                      486
# 3  AkHa00003224                 well                      364
# 4  AkHa00004224   tap_in_home_broken                      942
# 5  AkHa00005224          tap_in_home                      736
# 6  AkHa00006224          tap_in_home                      882
# 7  AkHa00007224          tap_in_home                      554
# 8  AkHa00008224                 well                      398
# 9  AkHa00009224                 well                      346

# %%
dfG = pd.read_sql_query("SELECT * FROM well_pollution LIMIT 10", ENGINE)
dfG
# Out:
#       source_id                date  \
# 0  KiRu28935224 2021-01-04 09:17:00
# 1  AkLu01628224 2021-01-04 09:53:00
# 2  HaZa21742224 2021-01-04 10:37:00
# 3  HaRu19725224 2021-01-04 11:04:00
# 4  SoRu35703224 2021-01-04 11:29:00
# 5  AkHa00070224 2021-01-04 11:42:00
# 6  HaSe21346224 2021-01-04 11:52:00
# 7  HaYa21468224 2021-01-04 12:03:00
# 8  SoRu36278224 2021-01-04 12:24:00
# 9  AkLu02155224 2021-01-04 12:29:00
#
#                                          description  pollutant_ppm  \
# 0                          Bacteria: Giardia Lamblia       0.000000
# 1                                  Bacteria: E. coli       0.000000
# 2  Inorganic contaminants: Zinc, Zinc, Lead, Cadmium       2.715000
# 3                                              Clean       0.028859
# 4                                  Bacteria: E. coli       0.000000
# 5                    Inorganic contaminants: Cadmium       5.467390
# 6                                              Clean       0.014038
# ...

# %%
df_1 = pd.read_sql_query("SELECT source_id, type_of_water_source AS Type, number_of_people_served AS Population FROM water_source LIMIT 5", ENGINE)
df_1
# Out:
#       source_id                Type  Population
# 0  AkHa00000224         tap_in_home         956
# 1  AkHa00001224  tap_in_home_broken         930
# 2  AkHa00002224  tap_in_home_broken         486
# 3  AkHa00003224                well         364
# 4  AkHa00004224  tap_in_home_broken         942

# %%
df_2 = pd.read_sql_query("SELECT DISTINCT type_of_water_source FROM water_source", ENGINE)
df_2
# Out:
#   type_of_water_source
# 0          tap_in_home
# 1   tap_in_home_broken
# 2                 well
# 3           shared_tap
# 4                river

# %%
df_2 = pd.read_sql_query("SELECT type_of_water_source, COUNT(type_of_water_source) FROM water_source GROUP BY type_of_water_source", ENGINE)
df_2
# Out:
#   type_of_water_source  COUNT(type_of_water_source)
# 0          tap_in_home                         7265
# 1   tap_in_home_broken                         5856
# 2                 well                        17383
# 3           shared_tap                         5767
# 4                river                         3379

# %%
visits = pd.read_sql_query("SELECT * FROM visits WHERE time_in_queue > 500 LIMIT 10", ENGINE)
visits
# Out:
#    record_id location_id     source_id      time_of_record  visit_count  \
# 0        899   SoRu35083  SoRu35083224 2021-01-16 10:14:00            6
# 1       2304   SoKo33124  SoKo33124224 2021-02-06 07:53:00            5
# 2       2315   KiRu26095  KiRu26095224 2021-02-06 14:32:00            3
# 3       3206   SoRu38776  SoRu38776224 2021-02-20 15:03:00            5
# 4       3701   HaRu19601  HaRu19601224 2021-02-27 12:53:00            3
# 5       4154   SoRu38869  SoRu38869224 2021-03-06 10:44:00            2
# 6       5483   AmRu14089  AmRu14089224 2021-03-27 18:15:00            4
# 7       9177   SoRu37635  SoRu37635224 2021-05-22 18:48:00            2
# 8       9648   SoRu36096  SoRu36096224 2021-05-29 11:24:00            2
# 9      11631   AkKi00881  AkKi00881224 2021-06-26 06:15:00            6
#
#    time_in_queue  assigned_employee_id
# 0            515                    28
# 1            512                    16
# 2            529                     8
# ...

# %%
df_2 = pd.read_sql_query("SELECT * FROM water_source WHERE source_id = 'AkRu05234224' OR source_id = 'HaZa21742224'", ENGINE)
df_2
# Out:
#       source_id type_of_water_source  number_of_people_served
# 0  AkRu05234224   tap_in_home_broken                      496
# 1  HaZa21742224                 well                      308

# %%
quality_score = pd.read_sql_query("SELECT * FROM water_quality WHERE subjective_quality_score = 10 AND visit_count = 2", ENGINE)
quality_score
# Out:
#      record_id  subjective_quality_score  visit_count
# 0           59                        10            2
# 1          137                        10            2
# 2          269                        10            2
# 3          363                        10            2
# 4          378                        10            2
# ..         ...                       ...          ...
# 213      57522                        10            2
# 214      58664                        10            2
# 215      58728                        10            2
# 216      59733                        10            2
# 217      59779                        10            2
#
# [218 rows x 3 columns]

# %%
df_4 = pd.read_sql_query("SELECT * FROM well_pollution WHERE results = 'Contaminated: Biological' OR results = 'dirty' LIMIT 5", ENGINE)
df_4
# Out:
#       source_id                date                description  pollutant_ppm  \
# 0  KiRu28935224 2021-01-04 09:17:00  Bacteria: Giardia Lamblia            0.0
# 1  AkLu01628224 2021-01-04 09:53:00          Bacteria: E. coli            0.0
# 2  SoRu35703224 2021-01-04 11:29:00          Bacteria: E. coli            0.0
# 3  SoRu36278224 2021-01-04 12:24:00  Parasite: Cryptosporidium            0.0
# 4  SoRu36313224 2021-01-04 13:46:00  Bacteria: Vibrio cholerae            0.0
#
#    biological                   results
# 0   495.89800  Contaminated: Biological
# 1     6.09608  Contaminated: Biological
# 2    22.50090  Contaminated: Biological
# 3   485.16200  Contaminated: Biological
# 4   182.88000  Contaminated: Biological

# %%
df_4 = pd.read_sql_query("SELECT * FROM well_pollution WHERE results = 'Clean' AND biological > 0.01 LIMIT 10", ENGINE)
df_4
# Out:
# Empty DataFrame
# Columns: [source_id, date, description, pollutant_ppm, biological, results]
# Index: []

# %%
df_4 = pd.read_sql_query("SELECT * FROM well_pollution WHERE description LIKE 'Clean%' AND biological > 0.01", ENGINE)
df_4
# Out:
# Empty DataFrame
# Columns: [source_id, date, description, pollutant_ppm, biological, results]
# Index: []

# %%
# After running the update from CMD for to change Clean Bacteria: E. coli to just Bacteria: E. coli
df_4 = pd.read_sql_query("SELECT * FROM well_pollution WHERE description LIKE 'Clean%' AND biological > 0.01", ENGINE)
df_4
# Out:
# Empty DataFrame
# Columns: [source_id, date, description, pollutant_ppm, biological, results]
# Index: []

# %%
import pandas as pd
df_5 = pd.read_sql_query("SELECT * FROM well_pollution WHERE pollutant_ppm > 0.01 AND results = 'Clean'", ENGINE)
df_5
# Out:
#          source_id                date description  pollutant_ppm  biological  \
# 0     HaRu19725224 2021-01-04 11:04:00       Clean       0.028859    0.000096
# 1     HaSe21346224 2021-01-04 11:52:00       Clean       0.014038    0.000090
# 2     AkRu05973224 2021-01-04 13:44:00       Clean       0.084344    0.000062
# 3     AkHa00706224 2021-01-04 16:10:00       Clean       0.086258    0.000042
# 4     HaRu20773224 2021-01-07 09:08:00       Clean       0.059968    0.000024
# ...            ...                 ...         ...            ...         ...
# 4911  SoIl32597224 2023-07-10 14:53:00       Clean       0.053880    0.000059
# 4912  AkRu04063224 2023-07-10 15:04:00       Clean       0.072542    0.000098
# 4913  AmAs10214224 2023-07-10 15:08:00       Clean       0.073552    0.000016
# 4914  KiIs23580224 2023-07-10 15:29:00       Clean       0.051757    0.000084
# 4915  AmRu14569224 2023-07-10 15:30:00       Clean       0.070287    0.000074
#
#      results
# 0      Clean
# ...
